# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import svm

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./UCI_Credit_Card.csv')
df = df.rename(columns={'default.payment.next.month': 'default', 'PAY_0': 'PAY_1'})
df = df.drop('ID',axis=1)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE         PAY_1         PAY_2         PAY_3         PAY_4         PAY_5         PAY_6      BILL_AMT1      BILL_AMT2     BILL_AMT3      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1      PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5       PAY_AMT6       default
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000   30000.000000  3.000000e+04   30000.000000   30000.000000   30000.000000   30000.000000  3.000000e+04   30000.00000   30000.000000   30000.000000   30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500     -0.016700     -0.133767     -0.166200     -0.220667     -0.266200     -0.291100   51223.330900   49179.075167  4.701315e+04   43262.948967   40311.400967   38871.760400    5663.580500  5.921163e+03    5225.68150    4826.076867    4799.387633    5215.502567      0.221200
# std     129747.661567      0.489129      0.790349      0.521970      9.217904      1.123802      1.197186      1.196868      1.169139      1.133187      1.149988   73635.860576   71173.768783  6.934939e+04   64332.856134   60797.155770   59554.107537   16563.280354  2.304087e+04   17606.96147   15666.159744   15278.305679   17777.465775      0.415062
# min      10000.000000      1.000000      0.000000      0.000000     21.000000     -2.000000     -2.000000     -2.000000     -2.000000     -2.000000     -2.000000 -165580.000000  -69777.000000 -1.572640e+05 -170000.000000  -81334.000000 -339603.000000       0.000000  0.000000e+00       0.00000       0.000000       0.000000       0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000     -1.000000     -1.000000     -1.000000     -1.000000     -1.000000     -1.000000    3558.750000    2984.750000  2.666250e+03    2326.750000    1763.000000    1256.000000    1000.000000  8.330000e+02     390.00000     296.000000     252.500000     117.750000      0.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000      0.000000      0.000000      0.000000      0.000000      0.000000      0.000000   22381.500000   21200.000000  2.008850e+04   19052.000000   18104.500000   17071.000000    2100.000000  2.009000e+03    1800.00000    1500.000000    1500.000000    1500.000000      0.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000      0.000000      0.000000      0.000000      0.000000      0.000000      0.000000   67091.000000   64006.250000  6.016475e+04   54506.000000   50190.500000   49198.250000    5006.000000  5.000000e+03    4505.00000    4013.250000    4031.500000    4000.000000      0.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000      8.000000      8.000000      8.000000      8.000000      8.000000      8.000000  964511.000000  983931.000000  1.664089e+06  891586.000000  927171.000000  961664.000000  873552.000000  1.684259e+06  896040.00000  621000.000000  426529.000000  528666.000000      1.000000

# %%
sampled_df = pd.DataFrame(columns=df.columns)
for class_label in [0,1]:
    class_data = df[df['default'] == class_label]
    sampled_data = class_data.sample(n=2000, random_state=37)
    sampled_df = pd.concat([sampled_df, sampled_data])

sampled_df.reset_index(drop=True, inplace=True)

# %%
X = df.drop('default', axis=1)
y = df['default']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=37)

# %%
# Logistic Regresssion
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

f1 = f1_score(y_test, y_pred)
acs  = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("accuracy score:", acs)

y_pred_prob = model.predict_proba(X_test)[:, 1]

fpr, tpr, _ = roc_curve(y_test, y_pred_prob)

roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - logistic regression')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.0
# accuracy score: 0.7773333333333333

# %%
# K Nearest Neighbours
knn = KNeighborsClassifier(n_neighbors = 20, p=2,  metric='euclidean')

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = knn.predict_proba(X_test)[:, 1]

fpr, tpr, _ = roc_curve(y_test, y_pred_prob)

roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for knn')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.13684657883552911
# Accuracy: 0.7743333333333333

# %%
# Create a neural network classifier
clf = MLPClassifier(hidden_layer_sizes=(128,64,32, ), max_iter=500, random_state=42)

# Train the classifier
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = clf.predict_proba(X_test)[:, 1]

fpr, tpr, _ = roc_curve(y_test, y_pred_prob)

roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for neural network')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.2909500986749366
# Accuracy: 0.7205555555555555

# %%
crm = df.corr()
plt.figure(figsize=(24, 20))
sns.heatmap(crm, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
#Data after selective col
selected_col = ['LIMIT_BAL', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'default'] 
updated_df = df[selected_col]

X = updated_df.drop('default', axis=1)
y = updated_df['default']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=37)

# %%
# Logistic regression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

f1 = f1_score(y_test, y_pred)
acs  = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("accuracy score:", acs)

y_pred_prob = model.predict_proba(X_test)[:, 1]

fpr, tpr, _ = roc_curve(y_test, y_pred_prob)

roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - logistic regression with feature selection')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.0
# accuracy score: 0.7774444444444445

# %%
# Knn Classifier
knn = KNeighborsClassifier(n_neighbors = 20, p=2,  metric='euclidean')

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = knn.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for knn with feature selection')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.1348028825773633
# Accuracy: 0.7732222222222223

# %%
#neural network
clf = MLPClassifier(hidden_layer_sizes=(128,64,32, ), max_iter=500, random_state=42)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = clf.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for neural network with feature selection')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.024038461538461536
# Accuracy: 0.7744444444444445

# %%
df = pd.read_csv('./credit-data.csv')

# %%
X = df.drop(['default10yr'], axis=1)
y = df['default10yr']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=37)

# %%
# Logistic regression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

f1 = f1_score(y_test, y_pred)
acs  = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("accuracy score:", acs)

y_pred_prob = model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve -  Logistic Regression with under sampleing ')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.6296296296296297
# accuracy score: 0.9

# %%
# Knn Classifier
knn = KNeighborsClassifier(n_neighbors = 5, p=2,  metric='euclidean')

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = knn.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for knn with under sampleing')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.3076923076923077
# Accuracy: 0.82

# %%
#neural network
clf = MLPClassifier(hidden_layer_sizes=(128,64,32, ), max_iter=500, random_state=42)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = clf.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for Neural Network with under sampleing')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.5969230769230769
# Accuracy: 0.7816666666666666

# %%
X = sampled_df.drop('default', axis=1)
y = sampled_df['default']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=37)
y_train = y_train.astype('int')
y_test = y_test.astype('int')

# %%
# Logistic regression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

f1 = f1_score(y_test, y_pred)
acs  = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("accuracy score:", acs)

y_pred_prob = model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - logistic regression')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.6265965439519158
# accuracy score: 0.5858333333333333

# %%
# Knn Classifier
knn = KNeighborsClassifier(n_neighbors = 5, p=2,  metric='euclidean')

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = knn.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for knn')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.5857260049220672
# Accuracy: 0.5791666666666667

# %%
#neural network
clf = MLPClassifier(hidden_layer_sizes=(128,64,32, ), max_iter=500, random_state=42)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print("F1 Score:", f1)
print("Accuracy:", accuracy)

y_pred_prob = clf.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve- for neural network')
plt.legend(loc="lower right")
plt.show()
# Out:
# F1 Score: 0.1630901287553648
# Accuracy: 0.5125
